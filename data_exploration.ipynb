# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %%
df_terror = pd.read_csv("data/globalterrorism.csv", encoding="ISO-8859-1")
df_country = pd.read_csv("data/country_attributes.csv")
# Out:
# C:\Users\Andre\AppData\Local\Temp\ipykernel_28724\45789844.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_terror = pd.read_csv("data/globalterrorism.csv", encoding="ISO-8859-1")

# %%
df_terror.head(50)
# Out:
#          eventid  iyear  imonth  iday           approxdate  extended  \
# 0   197000000001   1970       7     2                  NaN         0
# 1   197000000002   1970       0     0                  NaN         0
# 2   197001000001   1970       1     0                  NaN         0
# 3   197001000002   1970       1     0                  NaN         0
# 4   197001000003   1970       1     0                  NaN         0
# 5   197001010002   1970       1     1                  NaN         0
# 6   197001020001   1970       1     2                  NaN         0
# 7   197001020002   1970       1     2                  NaN         0
# 8   197001020003   1970       1     2                  NaN         0
# 9   197001030001   1970       1     3                  NaN         0
# 10  197001050001   1970       1     1                  NaN         0
# 11  197001060001   1970       1     6                  NaN         0
# 12  197001080001   1970       1     8                  NaN         0
# ...

# %%
df_terror[(df_terror['imonth'] == 9) & (df_terror['iyear'] == 2001) & (df_terror['iday'] == 11)]
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 73123  200109110001   2001       9    11        NaN         0        NaN
# 73124  200109110002   2001       9    11        NaN         0        NaN
# 73125  200109110003   2001       9    11        NaN         0        NaN
# 73126  200109110004   2001       9    11        NaN         0        NaN
# 73127  200109110005   2001       9    11        NaN         0        NaN
# 73128  200109110006   2001       9    11        NaN         0        NaN
# 73129  200109110007   2001       9    11        NaN         0        NaN
# 73130  200109110008   2001       9    11        NaN         0        NaN
#
#        country                       country_txt  region  \
# 73123       34                           Burundi      11
# 73124      229  Democratic Republic of the Congo      11
# 73125       97                            Israel      10
# 73126      217                     United States       1
# ...

# %%
df_country.head(10)
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
# 5      Albania          ALB
# 6      Albania          ALB
# 7      Albania          ALB
# 8      Albania          ALB
# 9      Albania          ALB
#
#                                                         Series Name  \
# 0                                                 Population, total
# 1                                      GDP per capita (current US$)
# 2  Unemployment, total (% of total labor force) (national estimate)
# 3   Political Stability and Absence of Violence/Terrorism: Estimate
# 4                                   Control of Corruption: Estimate
# 5                                                 Population, total
# 6                                      GDP per capita (current US$)
# 7  Unemployment, total (% of total labor force) (national estimate)
# ...
